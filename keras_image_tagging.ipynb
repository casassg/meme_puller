# %%
from keras.preprocessing import image
from keras.applications.inception_v3 import preprocess_input, decode_predictions, InceptionV3

import numpy as np
from IPython.display import Image, display
from IPython.core.display import HTML
import os

# If you want to use a GPU set its index here
os.environ['CUDA_VISIBLE_DEVICES'] = ''

# %%
model = InceptionV3(weights='imagenet')

# %%
img_path = 'flatirons.jpg'
img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
display(Image(img_path, width=200, height=200))

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=5))
# Out:
# Predicted: [[('n09193705', 'alp', 0.42403319), ('n09468604', 'valley', 0.15705636), ('n03792972', 'mountain_tent', 0.0339416), ('n04228054', 'ski', 0.032622397), ('n04252077', 'snowmobile', 0.024625663)]]

# %% [markdown]
# ## Helper functions
